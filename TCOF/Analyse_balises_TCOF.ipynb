# %% [markdown]
# # Compare les balises TCOF selon la source de téléchargement

# %% [markdown]
# Imports

# %%
import os
import pandas as pd
import re
import requests
import xml.etree.ElementTree as ET

# %% [markdown]
# Fonctions

# %%
def get_all_folder(path):
    directory = os.listdir(path)
    folder_list = []
    for folder in directory:
        if os.path.isdir(os.path.join(path, folder)):
            folder_list.append(folder)
    return folder_list

# %%
def add_path2corpus(path,corpus):
    new = '{}\{}'.format(path, corpus)
    return new

# %%
def flatten_list(liste):
    flattened_list = []
    for sublist in liste:
        for item in sublist:
            flattened_list.append(item)
    return flattened_list

# %%
def get_corpus_files(path):
    files = {}
    for file in os.listdir(path):
        if file.endswith('.xml'):
            files['xml']=file
        if file.endswith('.trs'):
            files['trs']=file
        if file.endswith('.wav'):
            files['wav']=file
        else:
            continue
    return files

# %%
def get_files_df(path):
    folders_genre=[add_path2corpus(path, folder) for folder in get_all_folder(path)] 
    list_corpus_path = []
    for folder in folders_genre:
        corpus_path = [add_path2corpus(folder, corpus) for corpus in get_all_folder(folder)]
        list_corpus_path.append(corpus_path)
    list_corpus_path = flatten_list(list_corpus_path)
    mydict = {}
    for corpus_path in list_corpus_path:
        dict_corpus = get_corpus_files(corpus_path)
        mydict[corpus_path]=dict_corpus
    df = pd.DataFrame.from_dict(mydict, orient='index').rename_axis('corpus').reset_index()
    return df

# %%
def add_corpus_names_col(df):
    wav = df['wav'].tolist()
    corpus_names = []
    for file in wav:
        pattern = r'^(.*)\.wav$'
        match = re.search(pattern, file)
        if match:
            corpus = match.group(1)
        corpus_names.append(corpus)
    df['corpus_name'] = corpus_names
    return df

# %%
def get_all_tagsname(xml_file):
    # Parse the XML file into an ElementTree object
    tree = ET.parse(xml_file)
    # Get the root element of the tree
    root = tree.getroot()
    # Initialize an empty set to store the tag names
    tag_names = set()
    # Iterate over all elements in the tree and add their tag names to the set
    for elem in root.iter():
        tag_names.add(elem.tag)
    # Return the set of tag names
    return tag_names

# %%
def is_same(list1, list2):
    s = set(list1)
    difference = [x for x in list2 if x not in s]
    if difference : 
        return difference
    else: 
        return True

# %%
def get_corpus_name(path):
    filename = re.search(r'[^\\\/]*?(?=\.\w+$)', path).group()
    return filename

# %%
def get_df_tags(xml_files, source):
    corpus_name = [get_corpus_name(xml_file) for xml_file in xml_files]
    corpus_source = [source for xml_file in range(len(xml_files))]
    tags_ = [get_all_tagsname(xml_file) for xml_file in xml_files]
    df = pd.DataFrame(list(zip(corpus_name, corpus_source, tags_)), columns = ['corpus_name','source','tags'])
    return df

# %% [markdown]
# ## Analyse de TCOF ZIP (depuis ortolang.fr)

# %%
#mettre le chemin du dossier téléchargé
path_zip = 'E:/Corpus/tcof/tcof/12/Corpus/Adultes'
#obtenir le dataframe avec le noms des fichiers du dossier dedans
df_zip = get_files_df(path_zip)

# %%
df_zip = add_corpus_names_col(df_zip)

# %%
df_zip
# Out:
#                                                 corpus  \
# 0    E:/Corpus/tcof/tcof/12/Corpus/Adultes\GenreNon...
# 1    E:/Corpus/tcof/tcof/12/Corpus/Adultes\GenreNon...
# 2    E:/Corpus/tcof/tcof/12/Corpus/Adultes\GenreNon...
# 3    E:/Corpus/tcof/tcof/12/Corpus/Adultes\GenreNon...
# 4    E:/Corpus/tcof/tcof/12/Corpus/Adultes\GenreNon...
# ..                                                 ...
# 234  E:/Corpus/tcof/tcof/12/Corpus/Adultes\Conversa...
# 235  E:/Corpus/tcof/tcof/12/Corpus/Adultes\Conversa...
# 236  E:/Corpus/tcof/tcof/12/Corpus/Adultes\Conversa...
# 237  E:/Corpus/tcof/tcof/12/Corpus/Adultes\Conversa...
# 238  E:/Corpus/tcof/tcof/12/Corpus/Adultes\Conféren...
#
#                          wav                      trs  \
# 0          plaid_haut_07.wav        plaid_haut_07.trs
# 1             sdl_bas_14.wav           sdl_bas_14.trs
# 2           forum_gom_14.wav         forum_gom_14.trs
# 3          voyage_jus_14.wav        voyage_jus_14.trs
# 4            chev_beu_sd.wav          chev_beu_sd.trs
# ..                       ...                      ...
# 234    automobile_gue_08.wav    automobile_gue_08.trs
# 235      tourisme_arn_15.wav      tourisme_arn_15.trs
# 236  photographie_cou_14.wav  photographie_cou_14.trs
# 237        voyage_con_15.wav        voyage_con_15.trs
# 238         these_pit_09.wav         these_pit_09.trs
#
#                          xml          corpus_name
# 0          plaid_haut_07.xml        plaid_haut_07
# 1             sdl_bas_14.xml           sdl_bas_14
# 2           forum_gom_14.xml         forum_gom_14
# 3          voyage_jus_14.xml        voyage_jus_14
# 4            chev_beu_sd.xml          chev_beu_sd
# ..                       ...                  ...
# 234    automobile_gue_08.xml    automobile_gue_08
# 235      tourisme_arn_15.xml      tourisme_arn_15
# 236  photographie_cou_14.xml  photographie_cou_14
# 237        voyage_con_15.xml        voyage_con_15
# 238         these_pit_09.xml         these_pit_09
#
# [239 rows x 5 columns]

# %%
#créer la liste de tous les chemins de fichier xml du tcof_zip
xml_files_zip = [r'{}\{}.xml'.format(x, y).replace('\\','/') for x,y in list(zip(df_zip['corpus'].tolist(), df_zip['corpus_name'].tolist()))]

# %%
#remplir le dataframe 
df_zip = get_df_tags(xml_files_zip, "zip_ortolang")

# %%
df_zip
# Out:
#              corpus_name        source  \
# 0          plaid_haut_07  zip_ortolang
# 1             sdl_bas_14  zip_ortolang
# 2           forum_gom_14  zip_ortolang
# 3          voyage_jus_14  zip_ortolang
# 4            chev_beu_sd  zip_ortolang
# ..                   ...           ...
# 234    automobile_gue_08  zip_ortolang
# 235      tourisme_arn_15  zip_ortolang
# 236  photographie_cou_14  zip_ortolang
# 237        voyage_con_15  zip_ortolang
# 238         these_pit_09  zip_ortolang
#
#                                                   tags
# 0    {resume, droit_acces, genre, support, autorisa...
# 1    {resume, droit_acces, genre, support, autorisa...
# 2    {resume, droit_acces, genre, support, autorisa...
# 3    {resume, droit_acces, genre, support, autorisa...
# 4    {resume, droit_acces, genre, support, autorisa...
# ..                                                 ...
# 234  {resume, droit_acces, genre, support, autorisa...
# 235  {resume, droit_acces, genre, support, autorisa...
# 236  {resume, droit_acces, genre, support, autorisa...
# 237  {resume, droit_acces, genre, support, autorisa...
# 238  {resume, droit_acces, genre, support, autorisa...
#
# [239 rows x 3 columns]

# %% [markdown]
# # TCOF REPOSITORY

# %%
#remettre ici le chemin du dossier où les fichiers ont été téléchargés
directory_path = r'E:/Corpus/tcof/TCOF_repo/'
directory_files = os.listdir(directory_path)
xml_files_repo = []
for file in directory_files:
    if file.endswith('.xml'):
        xml_files_repo.append(file)

# %%
xml_files_repo = ['{}{}'.format(directory_path, x) for x in xml_files_repo]

# %%
df = get_df_tags(xml_files_repo, "repository_ortolang")

# %%
df
# Out:
#               corpus_name               source  \
# 0            these_pit_09  repository_ortolang
# 1     consultation_ger_08  repository_ortolang
# 2     orthophonie2_san_10  repository_ortolang
# 3      orthophonie_san_10  repository_ortolang
# 4             pedi_gra_06  repository_ortolang
# ..                    ...                  ...
# 234  reunionkholle_moi_10  repository_ortolang
# 235      reunionpp_aar_08  repository_ortolang
# 236        see_reu_mat_08  repository_ortolang
# 237           taki_cam_13  repository_ortolang
# 238  tscha_cha_reu_ass_08  repository_ortolang
#
#                                                   tags
# 0    {resume, droit_acces, genre, support, autorisa...
# 1    {resume, droit_acces, genre, support, autorisa...
# 2    {resume, droit_acces, genre, support, autorisa...
# 3    {resume, droit_acces, genre, support, autorisa...
# 4    {resume, droit_acces, genre, support, autorisa...
# ..                                                 ...
# 234  {resume, droit_acces, genre, support, autorisa...
# 235  {resume, droit_acces, genre, support, autorisa...
# 236  {resume, droit_acces, genre, support, autorisa...
# 237  {resume, droit_acces, genre, support, autorisa...
# 238  {resume, droit_acces, genre, support, autorisa...
#
# [239 rows x 3 columns]

# %% [markdown]
# # TCOF CNRTL : à faire

# %% [markdown]
# # Comparaison des balises

# %%
#réunir toutes les dataframes dans un seul
df = df.append(df_zip)
# Out:
# C:\Users\maeva\AppData\Local\Temp\ipykernel_1984\4025343736.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_zip)

# %%
df
# Out:
#              corpus_name               source  \
# 0           these_pit_09  repository_ortolang
# 1    consultation_ger_08  repository_ortolang
# 2    orthophonie2_san_10  repository_ortolang
# 3     orthophonie_san_10  repository_ortolang
# 4            pedi_gra_06  repository_ortolang
# ..                   ...                  ...
# 234    automobile_gue_08         zip_ortolang
# 235      tourisme_arn_15         zip_ortolang
# 236  photographie_cou_14         zip_ortolang
# 237        voyage_con_15         zip_ortolang
# 238         these_pit_09         zip_ortolang
#
#                                                   tags
# 0    {resume, droit_acces, genre, support, autorisa...
# 1    {resume, droit_acces, genre, support, autorisa...
# 2    {resume, droit_acces, genre, support, autorisa...
# 3    {resume, droit_acces, genre, support, autorisa...
# 4    {resume, droit_acces, genre, support, autorisa...
# ..                                                 ...
# 234  {resume, droit_acces, genre, support, autorisa...
# 235  {resume, droit_acces, genre, support, autorisa...
# 236  {resume, droit_acces, genre, support, autorisa...
# 237  {resume, droit_acces, genre, support, autorisa...
# 238  {resume, droit_acces, genre, support, autorisa...
#
# [478 rows x 3 columns]

# %%
# prendre la liste des tags + l'intersection de toutes les listes
lists_tags = df['tags'].tolist()
results_union = set().union(*lists_tags)

# %%
# trouver les différences entre l'intersection de toutes les listes et la liste des tags d'un corpus donné
df['is_same'] = df['tags'].apply(lambda x:is_same(x, results_union))

# %%
#print all corpus with differents tags
df.loc[df['is_same'] != True]
# Out:
#              corpus_name               source  \
# 0           these_pit_09  repository_ortolang
# 1    consultation_ger_08  repository_ortolang
# 2    orthophonie2_san_10  repository_ortolang
# 3     orthophonie_san_10  repository_ortolang
# 9          apiculteur_sd  repository_ortolang
# ..                   ...                  ...
# 222        apiculteur_sd         zip_ortolang
# 223    professeur_cez_08         zip_ortolang
# 228      lecturecroco_sd         zip_ortolang
# 233    siderurgie_guy_10         zip_ortolang
# 238         these_pit_09         zip_ortolang
#
#                                                   tags  \
# 0    {resume, droit_acces, genre, support, autorisa...
# 1    {resume, droit_acces, genre, support, autorisa...
# 2    {resume, droit_acces, genre, support, autorisa...
# 3    {resume, droit_acces, genre, support, autorisa...
# 9    {nom, association, typologie, naissance, profe...
# ..                                                 ...
# 222  {nom, association, typologie, naissance, profe...
# 223  {resume, droit_acces, genre, support, autorisa...
# 228  {nom, association, typologie, naissance, profe...
# 233  {resume, droit_acces, genre, support, autorisa...
# 238  {resume, droit_acces, genre, support, autorisa...
#
#                        is_same
# 0                   [reviseur]
# 1                   [reviseur]
# 2                   [reviseur]
# 3                   [reviseur]
# 9    [transcripteur, reviseur]
# ..                         ...
# 222  [transcripteur, reviseur]
# 223                 [reviseur]
# 228  [transcripteur, reviseur]
# 233                 [reviseur]
# 238                 [reviseur]
#
# [94 rows x 4 columns]
